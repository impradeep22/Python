# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
diamond = sns.load_dataset('diamonds') # data import

# %%
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamond.head() # get the first 5 lines
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamond.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
# Point plot -- Plot the graph with one variable/column

# %%
sns.distplot(diamond['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.distplot(diamond['price'],kde = False)
# Out:
# C:\Users\pmaurya\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price'>

# %%
sns.kdeplot(diamond['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.rugplot(diamond['x'])
# Out:
# <AxesSubplot:xlabel='x'>

# %%
# Distribution plot -- Plot graph with variables  
tips = sns.load_dataset('tips') # data import

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.residplot(x = 'total_bill', y = 'tip', data = tips, lowess=True) # residal plot
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips) # by default distribution type or kind is scattered

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'hex', color = 'green') # change kind value to hex

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde', color = 'green') # change kind value to kde

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'reg', color = 'green') # change kind value to reg(regression)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'resid', color = 'green')

# %%
#Pair plot

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'smoker')

# %%
x = sns.pairplot(tips, hue = 'smoker')
x.map_diag(sns.distplot)
x.map_upper(sns.kdeplot)
x.map_upper(sns.rugplot)
# Out:
# C:\Users\pmaurya\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\pmaurya\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Categorial plot
#ploting a Graph with column with numeric datatype vs column with str datatype

# %%
sns.countplot(x = 'day',data=tips)#countplot except only on parameter
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.pointplot(x = 'day', y  = 'total_bill',data=tips, hue = 'sex', palatte = 'cool')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'day', y  = 'total_bill',data=tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.factorplot(x = 'day', y  = 'total_bill',data=tips, hue = 'sex',kind = 'swarm',palette = 'cool')
# Out:
# C:\Users\pmaurya\Anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.catplot(x = 'day', y  = 'total_bill',data=tips, hue = 'sex', kind = 'bar',palette = 'cool')

# %%
sns.barplot(x = 'day', y  = 'tip',data=tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x = 'day', y  = 'tip',data=tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x = 'day', y  = 'tip',data=tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
flights = sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# Matrix plot

# %%
tips2 = tips.corr()
sns.heatmap(tips2, annot = True, lw = 2, linecolor = '#fff',cmap = 'cool')
# Out:
# <AxesSubplot:>

# %%
flights2 = flights.corr()
sns.heatmap(flights2, annot = True, lw = 4, linecolor = '#fff')
# Out:
# <AxesSubplot:>

# %%
flights3 = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')
sns.heatmap(flights3, lw = 1, linecolor = '#fff', cmap = 'cool')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights3, lw = 1, linecolor = '#fff', cmap = 'cool')

# %%
#Grids --Styling a plot
# %matplotlib inline

# %%
sns.countplot(x = 'smoker', data = tips)
sns.set_context('paper')
sns.set_context('poster')
sns.set_context('notebook')

# %%
sns.countplot(x = 'smoker', data = tips)
sns.despine(left = True)

# %%
sns.countplot(x = 'smoker', data = tips)
sns.set_style('whitegrid')
