# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = sns.load_dataset('tips')

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df2 = pd.read_csv('ece.csv')

# %%
df2.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       ECTA.S19A1  2001.03         NaN         NaN      C  Dollars
# 1       ECTA.S19A1  2002.03         NaN         NaN      C  Dollars
# 2       ECTA.S19A1  2003.03         NaN         NaN      C  Dollars
# 3       ECTA.S19A1  2004.03     28005.1         NaN      F  Dollars
# 4       ECTA.S19A1  2005.03     30629.6         NaN      F  Dollars
#
#    Magnitude                                        Subject  \
# 0          6  Electronic Card Transactions (ANZSIC06) - ECT
# 1          6  Electronic Card Transactions (ANZSIC06) - ECT
# 2          6  Electronic Card Transactions (ANZSIC06) - ECT
# 3          6  Electronic Card Transactions (ANZSIC06) - ECT
# 4          6  Electronic Card Transactions (ANZSIC06) - ECT
#
#                                                Group Series_title_1  \
# 0  Total values - Electronic card transactions A/...         Actual
# ...

# %%
x1 = np.random.rand(100,5)

# %%
x2 = np.random.rand(10,5)

# %%
x2
# Out:
# array([[0.4705637 , 0.79597424, 0.6910974 , 0.58821965, 0.63888155],
#        [0.77566171, 0.56470452, 0.7213631 , 0.98781551, 0.75511335],
#        [0.91570105, 0.16960051, 0.02533734, 0.63876167, 0.2276213 ],
#        [0.33613321, 0.947824  , 0.14047989, 0.03762372, 0.96637245],
#        [0.10870318, 0.78349717, 0.44805871, 0.74171227, 0.50282992],
#        [0.46929648, 0.76436021, 0.40256869, 0.08746642, 0.1413791 ],
#        [0.52467217, 0.4506195 , 0.8225904 , 0.69318831, 0.67362941],
#        [0.37169355, 0.24658416, 0.98527581, 0.96336208, 0.38285528],
#        [0.24393301, 0.84516011, 0.49555458, 0.96391754, 0.55857978],
#        [0.65570788, 0.37057805, 0.98430675, 0.07204943, 0.81657924]])

# %%
df3 = pd.DataFrame(x1, columns = ['a','b','c','d','e'])

# %%
df4 = pd.DataFrame(x2, columns = ['a','b','c','d','e'])

# %%
df4.head()
# Out:
#           a         b         c         d         e
# 0  0.470564  0.795974  0.691097  0.588220  0.638882
# 1  0.775662  0.564705  0.721363  0.987816  0.755113
# 2  0.915701  0.169601  0.025337  0.638762  0.227621
# 3  0.336133  0.947824  0.140480  0.037624  0.966372
# 4  0.108703  0.783497  0.448059  0.741712  0.502830

# %%
#Point plot using pandas

# %%
df1.plot.scatter(x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#Line plot using pandas

# %%
df4.plot.line()
# Out:
# <AxesSubplot:>

# %%
df4.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df4.plot.density()#---kde and density plot are same
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#ploting graph for only one column
df4['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#Distribution plot using pandas

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['total_bill'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df4.plot(kind = 'area')
# Out:
# <AxesSubplot:>

# %%
df4.plot(y= 'e',kind = 'pie')
# Out:
# <AxesSubplot:ylabel='e'>

# %%
df1.plot(x='total_bill', y = 'tip', kind = 'hexbin',gridsize = 10, alpha = 0.5,figsize = (20,10), cmap = 'BuPu')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df4.plot.bar();

# %%
#Ref Documentation link: https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html
